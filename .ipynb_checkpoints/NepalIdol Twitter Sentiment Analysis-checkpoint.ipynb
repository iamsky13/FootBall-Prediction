# %%
import tweepy

from textblob import TextBlob

consumer_key= 'fJTxcFlZiLsT3IAzcdSbczRNe'
consumer_secret= 'IXtB7LX15ECrcpuJTMUNWhZe5zNWVFb6aLvTW7FGA1Pa8ER8Xm'

access_token='1482213768-KwQLRL7WDTX4qrJua3BD9NnfI5EamCpHQCfBo9l'
access_token_secret='C41uWxqOyhJ7pj1o70w2GKJaVpfG7hGRD2TIzZ1yUD6G8'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)


api = tweepy.API(auth)

public_tweets = api.search('Nepalidol')

for tweet in tweepy.Cursor(api.search,
                           q="nishan OR nishan bhattarai",
                           count=10,
                           result_type="recent",
                           include_entities=True,
                           lang="en").items():
    print(tweet.text)
    
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
print("")
# Out:
# A New message From Nishan Bhattarai.. https://t.co/4SERBWMnkb
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Few Clips to support Nishan Bhattarai . The video the proves that he can sing any kind of songs. https://t.co/Y5JRk3yINB
# Sentiment(polarity=0.2333333333333333, subjectivity=0.3333333333333333)
# @adhikarip420 Plz vote for Nishan bhattarai
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @bajgain_kushal: Vote for Nishan bhattarai....for the first Nepal Idol https://t.co/tZWov5NDF8
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# RT @bajgain_kushal: Vote for Nishan bhattarai....for the first Nepal Idol https://t.co/tZWov5NDF8
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# @desultory_man @baa_jhinga Nishan Bhattarai banera, usle fb ma j j post garcha tei post garera @Pramojan (idol_bhat… https://t.co/lIpmqOPQO2
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...
