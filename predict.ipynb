# %%
import pandas as pd
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from IPython.display import display
# Out:
# /home/aakash/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = pd.read_csv("final_dataset.csv")
display(data.head())
# acronym
# Div = League Division
# Date = Match Date (dd/mm/yy)
# HomeTeam = Home Team
# AwayTeam = Away Team
# FTHG and HG = Full Time Home Team Goals
# FTAG and AG = Full Time Away Team Goals
# FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
# FTR is our result
# Out:
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A     0     0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D     1     0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H     1     0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H     1     0   H
#
#    ...   BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0  ...       1.61    32  -0.25     2.13     2.06     1.86     1.81  2.79
# 1  ...       1.52    33  -0.50     2.07     2.00     1.90     1.85  2.25
# 2  ...       1.77    32   0.25     1.91     1.85     2.09     2.00  3.64
# 3  ...       1.67    31   0.25     2.35     2.26     2.03     1.67  4.68
# 4  ...       2.48    34  -1.50     1.81     1.73     2.20     2.14  1.25
#
#    PSCD   PSCA
# 0  3.16   2.89
# 1  3.15   3.86
# 2  3.54   2.16
# ...

# %%
# .shape[rows]= total match
n_matches = data.shape[0]
# display(n_matches)
# .shape[column]=total feature since one of them is label substract 1
n_features = data.shape[1]-1
# display(n_features)

n_homewins = len(data[data.FTR == 'H'])
# display(n_homewins)

win_rate = (float(n_homewins)/(n_matches))*100

print "Total matches :{}".format(n_matches)
print "Total features :{}".format(n_features)
print "Total homewins :{}".format(n_homewins)
print "Home percent wins :{}".format(win_rate)
# Out:
# Total matches :380
# Total features :64
# Total homewins :187
# Home percent wins :49.2105263158
